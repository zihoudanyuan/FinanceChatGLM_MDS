# %% [markdown]
# # 评估 硕士占比 python计算的准召，准确0.7，召回0.8

# %%
import json

# %%
n = []
with open('../机器爱学习_result_0812_v3_detail_debug5.json','rt') as f:
    for line in f:
        n.append(json.loads(line))

# %%
s = []
for line in n:
    if '硕士及以上人员占' in line['question']:
        s.append(line)

# %%
len(s)
# Out:
# 45

# %%
s[0]
# Out:
# {'id': 47,
#  'question': '华信新材在2019年的研发人员占职工人数比例是多少?请保留2位小数。',
#  'answer': '我不知道你想要任什么,可以提供更多信息吗?',
#  'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:江苏华信新材料股份有限公司||证券简称:华信新材||证券代码:300717\n- 华信新材(全称:江苏华信新材料股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为400 。\n 研发人员为55 。\n 研发人员比率为13.75 。\n 硕士人数为2 。\n 硕士以上人数为4 。\n 博士人数为2 。\n 博士以上人数为2。\n\n【提问】\n华信新材在2019年的研发人员占职工人数比例是多少?请保留2位小数。\n'}

# %%
s[1]
# Out:
# {'id': 145,
#  'question': '三棵树在2019年的研发人员占职工人数的比例是多少？请保留两位小数。',
#  'answer': '三棵树在2019年的研发人员占职工人数比例为: 0.11\n',
#  'prompt': '【背景知识】\n证券全称:三棵树涂料股份有限公司||证券简称:三棵树||证券代码:603737\n- 三棵树(全称:三棵树涂料股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为5163 。\n 研发人员为583 。\n 研发人员比率为11.29 。\n 硕士以上人数为177。\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n输出计算三棵树在2019年的研发人员占职工人数比例的Python代码,结果保留两位小数且不要带百分号。\n'}

# %%
s[2]
# Out:
# {'id': 337,
#  'question': '金堆城钼业股份有限公司在2019年中，研发人员占职工人数的比例是多少，结果请保留两位小数.',
#  'answer': '金堆城钼业股份有限公司在2019年中研发人员占职工人数比例为: 0.13\n',
#  'prompt': '【背景知识】\n证券全称:金堆城钼业股份有限公司||证券简称:金钼股份||证券代码:601958\n- 金钼股份(全称:金堆城钼业股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为5360 。\n 研发人员为713 。\n 研发人员比率为13.3 。\n 硕士人数为186 。\n 硕士以上人数为186。\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n输出计算金堆城钼业股份有限公司在2019年中研发人员占职工人数比例的Python代码,结果保留两位小数且不要带百分号。\n'}

# %%
s[3]
# Out:
# {'id': 399,
#  'question': '请问，雪浪环境2019年研发人员占职工人数的比例是多少?保留2位小数。',
#  'answer': '对不起，我不明白你的问题。你能否提供更多上下文或信息，以便我更好地回答你的问题？',
#  'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:无锡雪浪环境科技股份有限公司||证券简称:雪浪环境||证券代码:300385\n- 雪浪环境(全称:无锡雪浪环境科技股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为702 。\n 研发人员为172 。\n 研发人员比率为24.5 。\n 硕士人数为13 。\n 硕士以上人数为13。\n\n【提问】\n请问，雪浪环境2019年研发人员占职工人数的比例是多少?保留2位小数。\n'}

# %%
s[4]
# Out:
# {'id': 462,
#  'question': '2019年杰瑞股份研发人员占职工人数比例是多少?保留2位小数。',
#  'answer': '根据提供的背景知识，2019年杰瑞股份的研发费用为272653765.79元。要计算2019年杰瑞股份研发人员占职工人数比例，我们需要先计算出杰瑞股份的职工人数。假设杰瑞股份的职工人数为X，那么我们可以得到以下等式：\n\n研发费用 / X = 研发人员占职工人数比例\n\n将已知数据代入等式中，我们可以得到：\n\n272653765.79 / X = 研发人员占职工人数比例\n\n为了保留2位小数，我们需要将答案四舍五入到小数点后第二位。根据四舍五入的规则，如果小数点后第三位的数字大于等于5，则将第二位数字加1；否则，第二位数字不变。在这个问题中，小数点后第三位数字为7，大于等于5，所以我们需要将第二位数字2加1。因此，最终答案为：\n\n研发人员占职工人数比例 = 12.84%',
#  'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:烟台杰瑞石油服务集团股份有限公司||证券简称:杰瑞股份||证券代码:002353\n在2019年，杰瑞股份的研发费用为272653765.79元。\n【提问】\n2019年杰瑞股份研发人员占职工人数比例是多少?保留2位小数。\n'}

# %%
s[5]
# Out:
# {'id': 532,
#  'question': '黄石东贝电器股份有限公司在2019年的研发人员占职工人数的比例是多少?请保留两位小数。',
#  'answer': '12.99\n',
#  'prompt': '【背景知识】\n证券全称:黄石东贝电器股份有限公司||证券简称:东贝电器||证券代码:900956\n- 东贝电器(全称:黄石东贝电器股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为4819 。\n 研发人员为626 。\n 研发人员比率为12.99。\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n输出计算黄石东贝电器股份有限公司在2019年研发人员占职工人数比例的Python代码,结果保留两位小数且不要带百分号。\n'}

# %%
s[6]
# Out:
# {'id': 706,
#  'question': '2019年罗普斯金的研发人员占职工人数的比例是多少？请保留两位小数。',
#  'answer': '罗普斯金2019年研发人员占职工人数比例为： 0\n',
#  'prompt': '【背景知识】\n证券全称:中亿丰罗普斯金材料科技股份有限公司||证券简称:罗普斯金||证券代码:002333\n- 罗普斯金(全称:中亿丰罗普斯金材料科技股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为918 。\n 研发人员为141 。\n 研发人员比率为15.36。\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n请输出计算2019年罗普斯金研发人员占职工人数比例的Python代码，结果保留两位小数且不要带百分号。\n'}

# %%
n[10]
# Out:
# {'id': 1147,
#  'question': '四川宏达股份有限公司2019年的研发人员占职工人数比例是多少？请保留两位小数。',
#  'answer': '四川宏达股份有限公司2019年研发人员占职工人数比例为: 0.07\n',
#  'prompt': '【背景知识】\n证券全称:四川宏达股份有限公司||证券简称:宏达股份||证券代码:600331\n- 宏达股份(全称:四川宏达股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为3069 。\n 研发人员为205 。\n 研发人员比率为6.68 。\n 硕士以上人数为17。\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n输出计算四川宏达股份有限公司2019年研发人员占职工人数比例的Python代码,结果保留两位小数且不要带百分号。\n'}

# %%
sr = 0
srs = []
srs_id = []
bad_s = []
for si in s:
    if 'Python' in si['prompt']:
        sr += 1
        srs.append(si)
        srs_id.append(si['id'])
    else:
        bad_s.append(si)

# %%
sr
# Out:
# 21

# %%
srs
# Out:
# [{'id': 145,
#   'question': '三棵树在2019年的研发人员占职工人数的比例是多少？请保留两位小数。',
#   'answer': '三棵树在2019年的研发人员占职工人数比例为: 0.11\n',
#   'prompt': '【背景知识】\n证券全称:三棵树涂料股份有限公司||证券简称:三棵树||证券代码:603737\n- 三棵树(全称:三棵树涂料股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为5163 。\n 研发人员为583 。\n 研发人员比率为11.29 。\n 硕士以上人数为177。\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n输出计算三棵树在2019年的研发人员占职工人数比例的Python代码,结果保留两位小数且不要带百分号。\n'},
#  {'id': 337,
#   'question': '金堆城钼业股份有限公司在2019年中，研发人员占职工人数的比例是多少，结果请保留两位小数.',
#   'answer': '金堆城钼业股份有限公司在2019年中研发人员占职工人数比例为: 0.13\n',
#   'prompt': '【背景知识】\n证券全称:金堆城钼业股份有限公司||证券简称:金钼股份||证券代码:601958\n- 金钼股份(全称:金堆城钼业股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为5360 。\n 研发人员为713 。\n 研发人员比率为13.3 。\n 硕士人数为186 。\n 硕士以上人数为186。\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n输出计算金堆城钼业股份有限公司在2019年中研发人员占职工人数比例的Python代码,结果保留两位小数且不要带百分号。\n'},
#  {'id': 532,
#   'question': '黄石东贝电器股份有限公司在2019年的研发人员占职工人数的比例是多少?请保留两位小数。',
#   'answer': '12.99\n',
#   'prompt': '【背景知识】\n证券全称:黄石东贝电器股份有限公司||证券简称:东贝电器||证券代码:900956\n- 东贝电器(全称:黄石东贝电器股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为4819 。\n 研发人员为626 。\n 研发人员比率为12.99。\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n输出计算黄石东贝电器股份有限公司在2019年研发人员占职工人数比例的Python代码,结果保留两位小数且不要带百分号。\n'},
#  {'id': 706,
#   'question': '2019年罗普斯金的研发人员占职工人数的比例是多少？请保留两位小数。',
#   'answer': '罗普斯金2019年研发人员占职工人数比例为： 0\n',
#   'prompt': '【背景知识】\n证券全称:中亿丰罗普斯金材料科技股份有限公司||证券简称:罗普斯金||证券代码:002333\n- 罗普斯金(全称:中亿丰罗普斯金材料科技股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为918 。\n 研发人员为141 。\n 研发人员比率为15.36。\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n请输出计算2019年罗普斯金研发人员占职工人数比例的Python代码，结果保留两位小数且不要带百分号。\n'},
#  {'id': 1080,
#   'question': '2019年四川金时科技股份有限公司研发人员占职工人数比例为多少?保留2位小数。',
#   'answer': '0.06\n',
#   'prompt': '【背景知识】\n证券全称:四川金时科技股份有限公司||证券简称:金时科技||证券代码:002951\n- 金时科技(全称:四川金时科技股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为517 。\n 研发人员为33 。\n 研发人员比率为6.38 。\n 硕士以上人数为6。\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n输出四川金时科技股份有限公司2019年研发人员占职工人数比例的Python代码,结果保留两位小数且不要带百分号。\n'},
#  {'id': 1120,
#   'question': '浙江长城电工科技股份有限公司2019年研发人员占职工人数比例是多少?保留2位小数。',
#   'answer': '0.10182370820668693\n',
#   'prompt': '【背景知识】\n证券全称:浙江长城电工科技股份有限公司||证券简称:长城科技||证券代码:603897\n- 长城科技(全称:浙江长城电工科技股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为658 。\n 研发人员为67 。\n 研发人员比率为10.18。\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n请输出浙江长城电工科技股份有限公司2019年研发人员占职工人数比例的Python代码,结果保留两位小数且不要带百分号。\n'},
#  {'id': 1147,
#   'question': '四川宏达股份有限公司2019年的研发人员占职工人数比例是多少？请保留两位小数。',
#   'answer': '四川宏达股份有限公司2019年研发人员占职工人数比例为: 0.07\n',
#   'prompt': '【背景知识】\n证券全称:四川宏达股份有限公司||证券简称:宏达股份||证券代码:600331\n- 宏达股份(全称:四川宏达股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为3069 。\n 研发人员为205 。\n 研发人员比率为6.68 。\n 硕士以上人数为17。\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n输出计算四川宏达股份有限公司2019年研发人员占职工人数比例的Python代码,结果保留两位小数且不要带百分号。\n'},
#  {'id': 1206,
#   'question': '浙江航民股份有限公司2019年研发人员占职工人数比例是多少?保留2位小数。',
#   'answer': '0.10\n',
#   'prompt': '【背景知识】\n证券全称:浙江航民股份有限公司||证券简称:航民股份||证券代码:600987\n- 航民股份(全称:浙江航民股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为9633 。\n 研发人员为918 。\n 研发人员比率为9.53。\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n请输出浙江航民股份有限公司2019年研发人员占职工人数比例的Python代码,结果保留两位小数且不要带百分号。\n'},
#  {'id': 1218,
#   'question': '长虹华意压缩机股份有限公司2019年的研发人员占职工人数的比例是多少？请保留两位小数。',
#   'answer': '长虹华意压缩机股份有限公司2019年研发人员占职工人数比例为: 0.07\n',
#   'prompt': '【背景知识】\n证券全称:长虹华意压缩机股份有限公司||证券简称:长虹华意||证券代码:000404\n- 长虹华意(全称:长虹华意压缩机股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为7802 。\n 研发人员为570 。\n 研发人员比率为7.31 。\n 硕士以上人数为87。\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n输出长虹华意压缩机股份有限公司2019年研发人员占职工人数比例的Python代码，结果保留两位小数且不要带百分号。\n'},
#  {'id': 1237,
#   'question': '裕兴股份在2019年的研发人员占职工人数比例是多少？请保留两位小数。',
#   'answer': '裕兴股份2019年报的研发人员占职工人数比例为0.17\n',
#   'prompt': '【背景知识】\n证券全称:江苏裕兴薄膜科技股份有限公司||证券简称:裕兴股份||证券代码:300305\n- 裕兴股份(全称:江苏裕兴薄膜科技股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为321 。\n 研发人员为53 。\n 研发人员比率为16.51 。\n 硕士以上人数为10。\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n输出: 输出计算裕兴股份在2019年的研发人员占职工人数比例的Python代码,结果保留两位小数且不要带百分号。\n'},
#  {'id': 1391,
#   'question': '浙江仙通2019年的研发人员占职工人数的比例是多少？请保留两位小数。',
#   'answer': '浙江仙通2019年研发人员占职工人数比例为0.11\n',
#   'prompt': '【背景知识】\n证券全称:浙江仙通橡塑股份有限公司||证券简称:浙江仙通||证券代码:603239\n- 浙江仙通(全称:浙江仙通橡塑股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为1746 。\n 研发人员为200 。\n 研发人员比率为14.26。\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n输出浙江仙通2019年研发人员占职工人数比例的Python代码,结果保留两位小数且不要带百分号。\n'},
#  {'id': 2998,
#   'question': '福建省青山纸业股份有限公司在2019年的研发人员占职工人数比例是多少？（保留2位小数）',
#   'answer': '福建省青山纸业股份有限公司在2019年的研发人员占职工人数比例为:0.13\n',
#   'prompt': '【背景知识】\n证券全称:福建省青山纸业股份有限公司||证券简称:青山纸业||证券代码:600103\n- 青山纸业(全称:福建省青山纸业股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为3724 。\n 研发人员为468 。\n 研发人员比率为13.04。\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n请输出福建省青山纸业股份有限公司在2019年的研发人员占职工人数比例的Python代码,结果保留两位小数且不要带百分号。\n'},
#  {'id': 3147,
#   'question': '卫星化学股份有限公司在2019年的研发人员占职工人数比例为多少？请保留至小数点后两位。',
#   'answer': '卫星化学股份有限公司在2019年的研发人员占职工人数比例为:0.09\n',
#   'prompt': '【背景知识】\n证券全称:卫星化学股份有限公司||证券简称:卫星化学||证券代码:002648\n- 卫星化学(全称:卫星化学股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为2696 。\n 研发人员为240 。\n 研发人员比率为8.9 。\n 硕士以上人数为86。\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n输出卫星化学股份有限公司在2019年的研发人员占职工人数比例的Python代码,结果保留至小数点后两位且不要带百分号。\n'},
#  {'id': 3481,
#   'question': '在2019年，北京万集科技股份有限公司的研发人员占职工总人数的比例是多少？结果请保留两位小数。',
#   'answer': '北京万集科技股份有限公司在2019年研发人员占职工总人数比例为0.24\n',
#   'prompt': '【背景知识】\n证券全称:北京万集科技股份有限公司||证券简称:万集科技||证券代码:300552\n- 万集科技(全称:北京万集科技股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为1113 。\n 研发人员为272 。\n 研发人员比率为24.44 。\n 硕士人数为176 。\n 硕士以上人数为182 。\n 博士人数为6 。\n 博士以上人数为6。\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n请输出北京万集科技股份有限公司在2019年研发人员占职工总人数比例的Python代码,保留两位小数,不要带百分号。\n'},
#  {'id': 3503,
#   'question': '沈阳化工股份有限公司2019年研发人员占职工人数比例是多少?保留2位小数。',
#   'answer': '0.10\n',
#   'prompt': '【背景知识】\n证券全称:沈阳化工股份有限公司||证券简称:沈阳化工||证券代码:000698\n- 沈阳化工(全称:沈阳化工股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为2868 。\n 研发人员为280 。\n 研发人员比率为9.76。\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n输出计算沈阳化工股份有限公司2019年研发人员占职工人数比例的Python代码,结果保留两位小数且不要带百分号。\n'},
#  {'id': 3683,
#   'question': '2019年安泰科技股份有限公司研发人员占职工人数比例为多少?保留2位小数。',
#   'answer': '15.292003593890385\n',
#   'prompt': '【背景知识】\n证券全称:安泰科技股份有限公司||证券简称:安泰科技||证券代码:000969\n- 安泰科技(全称:安泰科技股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为5565 。\n 研发人员为851 。\n 研发人员比率为15.29 。\n 硕士人数为291 。\n 硕士以上人数为342 。\n 博士人数为51 。\n 博士以上人数为51。\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n请输出计算安泰科技股份有限公司2019年研发人员占职工人数比例的Python代码,结果保留两位小数且不要带百分号。\n'},
#  {'id': 3825,
#   'question': '陕西宝光真空电器股份有限公司在2019年的研发人员占职工人数比例是多少？请保留两位小数。',
#   'answer': '陕西宝光真空电器股份有限公司在2019年研发人员占职工人数比例为: 0.12\n',
#   'prompt': '【背景知识】\n证券全称:陕西宝光真空电器股份有限公司||证券简称:宝光股份||证券代码:600379\n- 宝光股份(全称:陕西宝光真空电器股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为1322 。\n 研发人员为163 。\n 研发人员比率为12.51 。\n 硕士人数为45 。\n 硕士以上人数为46 。\n 博士人数为1 。\n 博士以上人数为1。\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n输出计算陕西宝光真空电器股份有限公司在2019年研发人员占职工人数比例的Python代码,结果保留两位小数且不要带百分号。\n'},
#  {'id': 4442,
#   'question': '新疆熙菱信息技术股份有限公司2019年研发人员占职工人数比例是多少?保留2位小数。',
#   'answer': '新疆熙菱信息技术股份有限公司2019年研发人员占职工人数比例为: 0.75\n',
#   'prompt': '【背景知识】\n证券全称:新疆熙菱信息技术股份有限公司||证券简称:熙菱信息||证券代码:300588\n- 熙菱信息(全称:新疆熙菱信息技术股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为386 。\n 研发人员为288 。\n 研发人员比率为74.61 。\n 硕士以上人数为22。\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n输出: 输出新疆熙菱信息技术股份有限公司2019年研发人员占职工人数比例的Python代码,结果保留两位小数且不要带百分号。\n'},
#  {'id': 4575,
#   'question': '2019年金牌厨柜家居科技股份有限公司研发人员占职工人数比例为多少?保留2位小数。',
#   'answer': '0.30\n',
#   'prompt': '【背景知识】\n证券全称:金牌厨柜家居科技股份有限公司||证券简称:金牌厨柜||证券代码:603180\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n输出计算金牌厨柜家居科技股份有限公司2019年研发人员占职工人数比例的Python代码,结果保留两位小数且不要带百分号。\n'},
#  {'id': 4602,
#   'question': '上海环境在2019年的研发人员占职工人数的比例是多少？请保留两位小数。',
#   'answer': '0.16\n',
#   'prompt': '【背景知识】\n证券全称:上海环境集团股份有限公司||证券简称:上海环境||证券代码:601200\n- 上海环境(全称:上海环境集团股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为2535 。\n 研发人员为416 。\n 研发人员比率为16.0 。\n 硕士以上人数为202。\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n请输出计算上海环境在2019年的研发人员占职工人数比例的Python代码，结果保留两位小数且不要带百分号。\n'},
#  {'id': 4975,
#   'question': '2019年赛伍技术研发人员占职工人数比例是多少?保留2位小数。',
#   'answer': '2019年赛伍技术研发人员占职工人数比例为0.33\n',
#   'prompt': '【背景知识】\n证券全称:苏州赛伍应用技术股份有限公司||证券简称:赛伍技术||证券代码:603212\n\n【计算公式】\n研发人员占职工人数比例=研发人员数/职工总数\n【提问】\n输出计算2019年赛伍技术研发人员占职工人数比例的Python代码，结果保留两位小数且不要带百分号。\n'}]

# %%
14/20
# Out:
# 0.7

# %%
bad_s
# Out:
# [{'id': 399,
#   'question': '请问，雪浪环境2019年研发人员占职工人数的比例是多少?保留2位小数。',
#   'answer': '对不起,我不明白你的问题。你能否提供更多上下文或信息,以便我更好地回答你的问题?',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:无锡雪浪环境科技股份有限公司||证券简称:雪浪环境||证券代码:300385\n- 雪浪环境(全称:无锡雪浪环境科技股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为702 。\n 研发人员为172 。\n 研发人员比率为24.5 。\n 硕士人数为13 。\n 硕士以上人数为13。\n\n【提问】\n请问，雪浪环境2019年研发人员占职工人数的比例是多少?保留2位小数。\n'},
#  {'id': 462,
#   'question': '2019年杰瑞股份研发人员占职工人数比例是多少?保留2位小数。',
#   'answer': '根据提供的背景知识，我们无法找到关于杰瑞股份2019年研发人员占职工人数比例的具体数据。请提供足够的相关信息，或者根据已知信息无法回答该问题。',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:烟台杰瑞石油服务集团股份有限公司||证券简称:杰瑞股份||证券代码:002353\n在2019年，杰瑞股份的研发费用为272653765.79元。\n【提问】\n2019年杰瑞股份研发人员占职工人数比例是多少?保留2位小数。\n'},
#  {'id': 1137,
#   'question': '莱茵生物2019年的研发人员占职工人数的比例是多少？保留2位小数。',
#   'answer': '根据提供的背景知识，莱茵生物在2019年的研发费用为14682044.29元。现在需要回答的问题是：莱茵生物2019年的研发人员占职工人数的比例是多少？保留2位小数。\n\n为了回答这个问题，我们需要计算出2019年莱茵生物的职工人数。由于背景知识中没有提供确切的数字，我们无法直接计算出答案。因此，我们无法回答这个问题。\n\n答案：无法回答该问题。',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:桂林莱茵生物科技股份有限公司||证券简称:莱茵生物||证券代码:002166\n在2019年，莱茵生物的研发费用为14682044.29元。\n【提问】\n莱茵生物2019年的研发人员占职工人数的比例是多少？保留2位小数。\n'},
#  {'id': 1600,
#   'question': '沪宁股份2019年的研发人员占职工人数比例是多少?保留2位小数。',
#   'answer': '根据提供的背景知识，沪宁股份在2019年的研发费用为16741503.15元。现在需要回答的问题是：沪宁股份2019年的研发人员占职工人数比例是多少？保留2位小数。\n\n为了回答这个问题，我们需要计算出2019年沪宁股份的职工人数和研发人员的数量。然后将研发人员的数量除以职工人数，并将结果保留两位小数。\n\n根据提供的背景知识，无法得知2019年沪宁股份的职工人数和研发人员的数量。因此，无法回答这个问题。',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:杭州沪宁电梯部件股份有限公司||证券简称:沪宁股份||证券代码:300669\n在2019年，沪宁股份的研发费用为16741503.15元。\n【提问】\n沪宁股份2019年的研发人员占职工人数比例是多少?保留2位小数。\n'},
#  {'id': 1709,
#   'question': '玲珑轮胎2019年研发人员占职工人数比例是多少?保留2位小数。',
#   'answer': '【解答】\n\n根据给出的背景知识，玲珑轮胎在2019年的研发费用为729921426.00元。\n\n为了计算玲珑轮胎2019年研发人员占职工人数比例，我们需要先计算出2019年玲珑轮胎的职工人数。由于背景知识中没有给出具体的数字，我们无法直接计算出这个数字。因此，我们无法回答这个问题。\n\n根据已知信息无法回答该问题。',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:山东玲珑轮胎股份有限公司||证券简称:玲珑轮胎||证券代码:601966\n在2019年，玲珑轮胎的研发费用为729921426.00元。\n【提问】\n玲珑轮胎2019年研发人员占职工人数比例是多少?保留2位小数。\n'},
#  {'id': 1886,
#   'question': '2019年胜华新材研发人员占职工人数比例是多少?保留2位小数。',
#   'answer': '根据提供的背景知识，2019年胜华新材的研发费用为0.00元。因此，无法计算出研发人员占职工人数比例。答案为“无法计算”。',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:胜华新材料集团股份有限公司||证券简称:胜华新材||证券代码:603026\n在2019年，胜华新材的研发费用为0.00元。\n【提问】\n2019年胜华新材研发人员占职工人数比例是多少?保留2位小数。\n'},
#  {'id': 1908,
#   'question': '2019年保千里研发人员占职工人数比例是多少?保留2位小数。',
#   'answer': '根据提供的背景知识，2019年保千里研发费用为5578698.11元。我们需要计算出2019年保千里研发人员占职工人数比例。\n\n【计算】\n\n1. 首先，我们需要计算出2019年保千里职工总数。由于题目没有给出具体的数字，我们无法进行计算。因此，我们需要查找相关资料或者询问相关人员。\n\n2. 假设2019年保千里职工总数为X。\n\n3. 然后，我们需要计算出2019年保千里研发人员数量。根据背景知识，2019年保千里研发费用为5578698.11元。我们可以通过以下公式计算出研发人员数量：\n\n   2019年保千里研发人员数量 = 2019年保千里研发费用 / (2019年职工平均工资 - 2019年研发费用占职工平均工资的比例)\n\n   由于题目没有给出具体的数字，我们无法进行计算。因此，我们需要查找相关资料或者询问相关人员。\n\n4. 假设2019年保千里职工平均工资为A，2019年研发费用占职工平均工资的比例为B。\n\n5. 根据题目要求，我们需要保留2位小数。因此，我们需要对计算结果进行四舍五入，保留两位小数。\n\n【回答】\n\n根据提供的背景知识，我们无法回答该问题。因为没有提供足够的相关信息。',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:江苏保千里视像科技集团股份有限公司||证券简称:保千里||证券代码:600074\n在2019年，保千里的研发费用为5578698.11元。\n【提问】\n2019年保千里研发人员占职工人数比例是多少?保留2位小数。\n'},
#  {'id': 2101,
#   'question': '2019年众业达研发人员占职工人数比例是多少?保留2位小数。',
#   'answer': '根据给出的背景知识，2019年众业达的研发费用为35058128.07元。我们需要计算出众业达研发人员占职工人数比例。\n\n首先，我们需要计算出众业达的职工人数。由于题目没有给出具体数字，我们无法计算出具体的职工人数。因此，我们无法回答这个问题。\n\n答案：根据已知信息无法回答该问题。',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:众业达电气股份有限公司||证券简称:众业达||证券代码:002441\n在2019年，众业达的研发费用为35058128.07元。\n【提问】\n2019年众业达研发人员占职工人数比例是多少?保留2位小数。\n'},
#  {'id': 2212,
#   'question': '钢研高纳2019年研发人员占职工人数比例是多少?保留2位小数。',
#   'answer': '根据提供的背景知识，2019年钢研高纳的研发费用为66772514.23元。现在需要回答的问题是：钢研高纳2019年研发人员占职工人数比例是多少？保留2位小数。\n\n为了回答这个问题，我们需要计算出2019年钢研高纳的职工人数。然后，将研发费用除以职工人数，并将答案保留两位小数。\n\n【解答】\n\n1. 根据提供的背景知识，2019年钢研高纳的研发费用为66772514.23元。\n\n2. 为了计算出2019年钢研高纳的职工人数，我们需要知道一个比例：职工人数占总人数的比例。假设钢研高纳的总人数为N，那么职工人数就是N乘以这个比例。由于题目没有提供这个比例，我们需要根据已知信息进行估算。\n\n3. 假设钢研高纳的职工人数占总人数的比例为x，那么2019年钢研高纳的总人数就是N=x乘以总人数。根据题目，我们知道2019年钢研高纳的研发费用为66772514.23元，而研发费用占2019年总费用的比例为100%。因此，2019年总费用为66772514.23元除以100%，即66772514.23元。\n\n4. 根据题目，我们需要计算出2019年钢研高纳的职工人数。假设职工人数为P，那么2019年钢研高纳的总人数就是P+1（因为题目没有说明是否包括钢研高纳的董事长、总经理等高级管理人员）。根据题目，2019年钢研高纳的研发费用为66772514.23元，而研发费用占2019年总费用的比例为100%。因此，2019年总费用为66772514.23元除以100%，即66772514.23元。\n\n5. 将2019年总费用除以总人数，得到2019年钢研高纳的总人数为N=66772514.23元除以（x乘以总人数）。将这个式子代入职工人数的表达式中，得到2019年钢研高纳的职工人数为N=66772514.23元除以（x乘以总人数）乘以（1-x），即N=（66772514.23元除以（x乘以总人数））乘以0.9。\n\n6. 由于题目没有提供钢研高纳的总人数，我们需要根据已知信息进行估算。假设钢研高纳的总人数为100000000，那么2019年钢研高纳的总人数就是100000000乘以x。将这个式子代入职工人数的表达式中，得到2019年钢研高纳的职工人数为N=（66772514.23元除以（100000000乘以x））乘以0.9，即N=（66772514.23元除以100000000乘以x）乘以0.9。\n\n7. 由于题目没有提供钢研高纳的总人数，我们需要根据已知信息进行估算。假设钢研高纳的总人数为100000000，那么2019年钢研高纳的总人数就是100000000乘以x。将这个式子代入职工人数的表达式中，得到2019年钢研高纳的职工人数为N=（66772514.23元除以（100000000乘以x））乘以0.9，即N=（66772514.23元除以100000000乘以x）乘以0.9。\n\n8. 将N的表达式代入职工人数占职工人数比例的表达式中，得到钢研高纳2019年研发人员占职工人数比例为x=N除以（N乘以0.9）。将N的表达式代入这个式子中，得到钢研高纳2019年研发人员占职工人数比例为x=1除以1.1。\n\n9. 将x乘以100，得到钢研高纳2019年研发人员占职工人数比例为90.9%。\n\n10. 因此，钢研高纳2019年研发人员占职工人数比例为90.9%。',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:北京钢研高纳科技股份有限公司||证券简称:钢研高纳||证券代码:300034\n在2019年，钢研高纳的研发费用为66772514.23元。\n【提问】\n钢研高纳2019年研发人员占职工人数比例是多少?保留2位小数。\n'},
#  {'id': 2320,
#   'question': '莱宝高科2019年研发人员占职工人数比例是多少?保留2位小数。',
#   'answer': '【解答】\n根据提供的背景知识，我们得知莱宝高科在2019年的研发费用为199117780.32元。\n\n为了回答问题，我们需要计算莱宝高科2019年研发人员占职工人数比例。\n\n假设莱宝高科2019年的职工人数为x，那么该公司的研发人员数量为x*1000（假设公司员工总数为1000人）。\n\n研发人员占职工人数比例 = (研发费用 / (职工人数 * 1000)) * 100%\n\n将提供的数值代入公式，得到：\n\n(199117780.32 / (x * 1000)) * 100% = (199117780.32 / (x * 1000)) * 100%\n\n为了保留2位小数，我们需要将结果四舍五入到小数点后第二位。\n\n综上所述，莱宝高科2019年研发人员占职工人数比例约为199.12%。',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:深圳莱宝高科技股份有限公司||证券简称:莱宝高科||证券代码:002106\n在2019年，莱宝高科的研发费用为199117780.32元。\n【提问】\n莱宝高科2019年研发人员占职工人数比例是多少?保留2位小数。\n'},
#  {'id': 2486,
#   'question': '2019年神马实业股份有限公司研发人员占职工人数比例为多少?保留2位小数。',
#   'answer': '我不知道你的问题是什么,因为你只写了“任”字,没有提供任何上下文或问题。请提供更多信息,让我更好地回答你的问题。',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:神马实业股份有限公司||证券简称:神马股份||证券代码:600810\n- 神马股份(全称:神马实业股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为6864 。\n 研发人员为432 。\n 研发人员比率为6.29。\n\n【提问】\n2019年神马实业股份有限公司研发人员占职工人数比例为多少?保留2位小数。\n'},
#  {'id': 2605,
#   'question': '2019年长江投资研发人员占职工人数比例是多少?保留2位小数。',
#   'answer': '根据提供的背景知识，2019年长江投资的研发费用为6509939.78，长期股权投资为86450754.59。但是，要回答这个问题，我们还需要知道长江投资的总职工人数。假设长江投资的总职工人数为10000000，那么2019年长江投资研发人员占职工人数比例为：\n\n2019年长江投资研发人员占职工人数比例 = (6509939.78 / 10000000) * 100% ≈ 6.51%\n\n因此，2019年长江投资研发人员占职工人数比例约为6.51%。',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:长发集团长江投资实业股份有限公司||证券简称:长江投资||证券代码:600119\n在2019年，长江投资的研发费用为6509939.78,\n 投资收益为-8438042.73元。\n在2019年，长江投资的长期股权投资为86450754.59元。\n【提问】\n2019年长江投资研发人员占职工人数比例是多少?保留2位小数。\n'},
#  {'id': 2775,
#   'question': '粤水电2019年研发人员占职工人数比例是多少?保留2位小数。',
#   'answer': '根据提供的背景知识，我们无法找到粤水电2019年研发人员占职工人数比例的具体数据。请提供足够的相关信息，以便我们为您提供准确的答案。',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:广东水电二局股份有限公司||证券简称:粤水电||证券代码:002060\n在2019年，粤水电的研发费用为34906917.44元。\n【提问】\n粤水电2019年研发人员占职工人数比例是多少?保留2位小数。\n'},
#  {'id': 2874,
#   'question': '陕鼓动力2019年研发人员占职工人数比例是多少?保留2位小数。',
#   'answer': '根据提供的背景知识，我们无法找到关于2019年陕鼓动力研发人员占职工人数比例的具体数据。请提供更多相关信息，以便我们能够回答您的问题。',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:西安陕鼓动力股份有限公司||证券简称:陕鼓动力||证券代码:601369\n在2019年，陕鼓动力的研发费用为254809547.24元。\n【提问】\n陕鼓动力2019年研发人员占职工人数比例是多少?保留2位小数。\n'},
#  {'id': 2998,
#   'question': '福建省青山纸业股份有限公司在2019年的研发人员占职工人数比例是多少？（保留2位小数）',
#   'answer': '对不起,我不明白您想要表达什么。您能否提供更多上下文或者详细描述您的问题或需要帮助的内容?这样我才能更好地回答您的问题。谢谢!',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:福建省青山纸业股份有限公司||证券简称:青山纸业||证券代码:600103\n- 青山纸业(全称:福建省青山纸业股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为3724 。\n 研发人员为468 。\n 研发人员比率为13.04。\n\n【提问】\n福建省青山纸业股份有限公司在2019年的研发人员占职工人数比例是多少？（保留2位小数）\n'},
#  {'id': 3053,
#   'question': '2019年华能国际研发人员占职工人数比例是多少?保留2位小数。',
#   'answer': '根据给出的背景知识，华能国际电力股份有限公司的证券代码为600011，2019年研发费用为65021719.00元。\n\n为了回答问题，我们需要计算2019年华能国际研发人员占职工人数比例。首先，我们需要计算出2019年公司的职工人数。由于背景知识中没有给出具体的数字，我们无法计算出准确的职工人数。因此，我们无法回答这个问题。\n\n答案：根据已知信息无法回答该问题。',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:华能国际电力股份有限公司||证券简称:华能国际||证券代码:600011\n在2019年，华能国际的研发费用为65021719.00元。\n【提问】\n2019年华能国际研发人员占职工人数比例是多少?保留2位小数。\n'},
#  {'id': 3102,
#   'question': '西安环球印务股份有限公司在2019年的研发人员占职工人数的比例保留到小数点后两位是多少？',
#   'answer': '我不知道您需要什么回答,因为您只输入了一个汉字:“任”。如果您有任何问题或需要帮助,请提供更多信息,我将尽力回答。',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:西安环球印务股份有限公司||证券简称:环球印务||证券代码:002799\n- 环球印务(全称:西安环球印务股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为1002 。\n 研发人员为196 。\n 研发人员比率为19.56 。\n 硕士以上人数为5。\n\n【提问】\n西安环球印务股份有限公司在2019年的研发人员占职工人数的比例保留到小数点后两位是多少？\n'},
#  {'id': 3147,
#   'question': '卫星化学股份有限公司在2019年的研发人员占职工人数比例为多少？请保留至小数点后两位。',
#   'answer': '对不起,我不太明白你的问题。能否提供更多的上下文或信息,以便更好地回答你的问题?',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:卫星化学股份有限公司||证券简称:卫星化学||证券代码:002648\n- 卫星化学(全称:卫星化学股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为2696 。\n 研发人员为240 。\n 研发人员比率为8.9 。\n 硕士以上人数为86。\n\n【提问】\n卫星化学股份有限公司在2019年的研发人员占职工人数比例为多少？请保留至小数点后两位。\n'},
#  {'id': 3241,
#   'question': '2019年鲁西化工研发人员占职工人数比例是多少?保留2位小数。',
#   'answer': '根据给出的背景知识，2019年鲁西化工的研发费用为572226061.23元。要求求出2019年鲁西化工研发人员占职工人数比例。\n\n解答过程：\n\n1. 计算2019年鲁西化工的职工人数。由于题目中没有给出，我们需要查找相关资料或者推算出来。在互联网上搜索相关信息，可以找到鲁西化工2019年的年报，其中给出了职工人数为10200人。\n\n2. 计算2019年鲁西化工的研发人员人数。根据题目，我们知道研发费用为572226061.23元，而研发费用占职工人数的比例为研发费用除以职工人数。因此，研发人员人数为：\n\n研发人员人数 = 研发费用 ÷ 职工人数\n              = 572226061.23 ÷ 10200\n              = 57222606123 / 10000\n              = 572226.06123\n\n3. 计算2019年鲁西化工研发人员占职工人数比例。将研发人员人数除以职工人数，再将结果乘以100，即可得到比例：\n\n研发人员占职工人数比例 = 研发人员人数 ÷ 职工人数 × 100\n                                     = 572226.06123 ÷ 10200 × 100\n                                     = 5.7222606123 × 100\n                                     ≈ 5.72%\n\n因此，2019年鲁西化工研发人员占职工人数比例约为5.72%。',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:鲁西化工集团股份有限公司||证券简称:鲁西化工||证券代码:000830\n在2019年，鲁西化工的研发费用为572226061.23元。\n【提问】\n2019年鲁西化工研发人员占职工人数比例是多少?保留2位小数。\n'},
#  {'id': 4121,
#   'question': '海伦哲2019年研发人员占职工人数比例是多少?保留2位小数。',
#   'answer': '根据提供的背景知识，海伦哲是一家专用车辆股份有限公司，证券代码为300201。在2019年，海伦哲的研发费用为67075890.56元。\n\n然而，要回答这个问题，我们还需要提供海伦哲2019年职工总人数。如果我们没有这个数据，我们无法计算海伦哲2019年研发人员占职工人数比例。因此，我们无法回答这个问题。\n\n根据已知信息无法回答该问题。',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:徐州海伦哲专用车辆股份有限公司||证券简称:海伦哲||证券代码:300201\n在2019年，海伦哲的研发费用为67075890.56元。\n【提问】\n海伦哲2019年研发人员占职工人数比例是多少?保留2位小数。\n'},
#  {'id': 4433,
#   'question': '乐歌股份2019年研发人员占职工人数比例是多少?保留2位小数。',
#   'answer': '根据提供的背景知识，乐歌股份在2019年的研发费用为41184557.02元。要求计算乐歌股份2019年研发人员占职工人数比例。\n\n解答过程：\n1. 计算乐歌股份2019年总人数：41184557.02 ÷ 294092019 = 15.79%。\n2. 计算乐歌股份2019年研发人员数量：由于题目中未提供，我们无法计算。\n3. 计算乐歌股份2019年研发人员占职工人数比例：将乐歌股份2019年研发人员数量代入公式，得到比例为：15.79% ÷ x = 15.79%。\n4. 解方程得到x：x = 15.79% ÷ 15.79% = 100%。\n\n因此，乐歌股份2019年研发人员占职工人数比例为100%，即答案为100%。',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:乐歌人体工学科技股份有限公司||证券简称:乐歌股份||证券代码:300729\n在2019年，乐歌股份的研发费用为41184557.02元。\n【提问】\n乐歌股份2019年研发人员占职工人数比例是多少?保留2位小数。\n'},
#  {'id': 4711,
#   'question': '西大门2019年研发人员占职工人数比例是多少?保留2位小数。',
#   'answer': '对不起，我不知道你在问什么。能否提供更多上下文或信息，以便更好地回答您的问题？',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:浙江西大门新材料股份有限公司||证券简称:西大门||证券代码:605155\n\n【提问】\n西大门2019年研发人员占职工人数比例是多少?保留2位小数。\n'},
#  {'id': 4720,
#   'question': '兆驰股份在2019年的研发人员占职工人数比例是多少？保留两位小数。',
#   'answer': '根据提供的背景知识，我们无法找到关于兆驰股份在2019年研发人员占职工人数比例的具体数据。因此，我们无法回答这个问题。答案为“根据已知信息无法回答该问题”或“没有提供足够的相关信息”。',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:深圳市兆驰股份有限公司||证券简称:兆驰股份||证券代码:002429\n在2019年，兆驰股份的研发费用为295725486.76元。\n【提问】\n兆驰股份在2019年的研发人员占职工人数比例是多少？保留两位小数。\n'},
#  {'id': 4792,
#   'question': '2019年凯马股份研发人员占职工人数比例是多少?保留2位小数。',
#   'answer': '【解答】\n\n根据提供的背景知识，我们得知2019年凯马股份的研发费用为37671654.69元。\n\n【提问】\n2019年凯马股份研发人员占职工人数比例是多少?保留2位小数。\n\n【解答】\n\n要求计算凯马股份2019年研发人员占职工人数比例，我们需要知道2019年凯马股份的总职工人数。\n\n假设2019年凯马股份的总职工人数为x，则根据比例关系，有：\n\n研发人员占比 = 研发费用 / 总职工人数\n\n将已知数据代入，得：\n\n研发人员占比 = 37671654.69 / x\n\n为了保留2位小数，我们将答案保留两位小数，得：\n\n研发人员占比 ≈ 37671654.69 / x ≈ 0.377\n\n因此，2019年凯马股份研发人员占职工人数比例约为37.7%。',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:恒天凯马股份有限公司||证券简称:凯马股份||证券代码:900953\n在2019年，凯马股份的研发费用为37671654.69元。\n【提问】\n2019年凯马股份研发人员占职工人数比例是多少?保留2位小数。\n'},
#  {'id': 4843,
#   'question': '2019年雅化集团研发人员占职工人数比例是多少?保留2位小数。',
#   'answer': '根据提供的背景知识，2019年雅化集团的研发费用为73579230.46元。要计算研发人员占职工人数比例，我们需要知道2019年雅化集团的职工人数。由于题目没有提供这一信息，我们无法计算研发人员占职工人数比例。所以答案是：根据已知信息无法回答该问题。',
#   'prompt': '【任务要求】\n请按照以下的步骤和要求，回答提问：\n第一，读取并理解【背景知识】。\n第二，财务指标的增长率【背景知识】里已算好，直接取即可。\n第三，整理你找到或计算出的数据。若涉及数字，请用纯数字。\n第四，若回答需要计算，请明确并简洁地给出计算步骤。\n第五，遵守小数点的要求，确保答案精确性。\n第六，用中文表述并回答问题。\n第七，涉及比率，请用百分比% 。\n如果无法从中得到答案，请说 “根据已知信息无法回答该问题” 或 “没有提供足够的相关信息”。答案请使用中文。\n【背景知识】\n证券全称:四川雅化实业集团股份有限公司||证券简称:雅化集团||证券代码:002497\n在2019年，雅化集团的研发费用为73579230.46元。\n【提问】\n2019年雅化集团研发人员占职工人数比例是多少?保留2位小数。\n'}]

# %%
len(bad_s)
# Out:
# 25

# %% [raw]
# 漏召5个，召回率

# %%
20/25
# Out:
# 0.8

# %% [raw]
# 准确率0.7，召回率0.8

# %% [markdown]
# ##

# %% [raw]
# 走成python计算有22/45

# %%
s[5]
# Out:
# {'id': 532,
#  'question': '黄石东贝电器股份有限公司在2019年的研发人员占职工人数的比例是多少?请保留两位小数。',
#  'answer': '黄石东贝电器股份有限公司在2019年的研发人员占职工人数比例为12.99%\n',
#  'prompt': '【背景知识】\n证券全称:黄石东贝电器股份有限公司||证券简称:东贝电器||证券代码:900956\n- 东贝电器(全称:黄石东贝电器股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为4819 。\n 研发人员为626 。\n 研发人员比率为12.99。\n\n【提问】\n输出计算黄石东贝电器股份有限公司在2019年的研发人员占职工人数比例的Python代码，保留两位小数。\n'}

# %%
s[6]
# Out:
# {'id': 706,
#  'question': '2019年罗普斯金的研发人员占职工人数的比例是多少？请保留两位小数。',
#  'answer': '15.36\n',
#  'prompt': '【背景知识】\n证券全称:中亿丰罗普斯金材料科技股份有限公司||证券简称:罗普斯金||证券代码:002333\n- 罗普斯金(全称:中亿丰罗普斯金材料科技股份有限公司)的2019年报内容:\n信息来源为年度报告 。\n 职工人数为918 。\n 研发人员为141 。\n 研发人员比率为15.36。\n\n【提问】\n输出计算2019年罗普斯金研发人员占职工人数比例的Python代码，保留两位小数。\n'}

# %%
o = []
with open('../机器爱学习_result_0812_v2.json','rt') as f:
    for line in f:
        o.append(json.loads(line))

# %%
for line in o:
    if line['id'] in srs_id:
        print(line)
# Out:
# {'id': 47, 'question': '华信新材在2019年的研发人员占职工人数比例是多少?请保留2位小数。', 'answer': '根据【背景知识】，华信新材在2019年的职工人数为400人，而研发人员为55人。因此，华信新材在2019年的研发人员占职工人数比例为：\n\n研发人员 ÷ 职工人数 = 55 ÷ 400 = 0.1375\n\n答案为0.1375，保留2位小数。'}
# {'id': 145, 'question': '三棵树在2019年的研发人员占职工人数的比例是多少？请保留两位小数。', 'answer': '根据【背景知识】，我们得知三棵树在2019年的职工人数为5163人，研发人员为583人，且研发人员比率为11.29。\n\n要求计算三棵树在2019年的研发人员占职工人数的比例。\n\n【解答】\n\n根据公式，研发人员占职工人数的比例 = 研发人员 / 职工人数 × 100%。\n\n将数据代入公式，得到：11.29 / 5163 × 100% ≈ 2.15%。\n\n所以，三棵树在2019年的研发人员占职工人数的比例约为2.15%。'}
# {'id': 337, 'question': '金堆城钼业股份有限公司在2019年中，研发人员占职工人数的比例是多少，结果请保留两位小数.', 'answer': '根据提供的背景知识，金堆城钼业股份有限公司在2019年的年报中，研发人员为713，职工人数为5360。要求计算研发人员占职工人数的比例，结果保留两位小数。\n\n【解答】\n\n1. 计算研发人员占职工人数的比例：\n\n研发人员占比 = 研发人员 / 职工人数\n\n研发人员占比 = 713 / 5360 ≈ 0.1315\n\n2. 将结果保留两位小数：\n\n研发人员占职工人数的比例 ≈ 0.13\n\n【答案】\n\n金堆城钼业股份有限公司在2019年中，研发人员占职工人数的比例约为0.13，结果保留两位小数。'}
# {'id': 532, 'question': '黄石东贝电器股份有限公司在2019年的研发人员占职工人数的比例是多少?请保留两位小数。', 'answer': '根据【背景知识】，黄石东贝电器股份有限公司在2019年的研发人员为626，职工人数为4819。要求计算该公司在2019年的研发人员占职工人数的比例。\n\n【计算】\n\n研发人员占职工人数的比例 = 研发人员 ÷ 职工人数 × 100%\n\n将数据代入公式，得到：\n\n研发人员占职工人数的比例 = 626 ÷ 4819 × 100% ≈ 13.47%\n\n【答案】\n\n黄石东贝电器股份有限公司在2019年的研发人员占职工人数的比例约为13.47%。'}
# {'id': 706, 'question': '2019年罗普斯金的研发人员占职工人数的比例是多少？请保留两位小数。', 'answer': '根据提供的背景知识，我们可以知道罗普斯金是一家股份有限公司，全称为中亿丰罗普斯金材料科技股份有限公司，证券简称罗普斯金，证券代码为002333。在2019年罗普斯金的年报中，职工人数为918人，研发人员为141人，研发人员比率为15.36。\n\n因此，2019年罗普斯金的研发人员占职工人数的比例为141/918=0.1536，即15.36%。'}
# {'id': 1080, 'question': '2019年四川金时科技股份有限公司研发人员占职工人数比例为多少?保留2位小数。', 'answer': '根据【背景知识】，2019年四川金时科技股份有限公司的职工人数为517人，研发人员为33人，且研发人员比率为6.38。\n\n因此，2019年四川金时科技股份有限公司研发人员占职工人数比例为：\n\n研发人员占比 = 研发人员 ÷ 职工人数 × 100%\n\n= 33 ÷ 517 × 100% ≈ 6.53%\n\n答案为：6.53%（保留2位小数）。'}
# {'id': 1120, 'question': '浙江长城电工科技股份有限公司2019年研发人员占职工人数比例是多少?保留2位小数。', 'answer': '根据提供的背景知识，浙江长城电工科技股份有限公司2019年的职工人数为658人，研发人员为67人。因此，浙江长城电工科技股份有限公司2019年研发人员占职工人数比例为：\n\n67 / 658 ≈ 0.1018\n\n答案为10.18%，保留2位小数。'}
# {'id': 1147, 'question': '四川宏达股份有限公司2019年的研发人员占职工人数比例是多少？请保留两位小数。', 'answer': '根据【背景知识】，四川宏达股份有限公司2019年的研发人员为205人，职工人数为3069人。所以，四川宏达股份有限公司2019年的研发人员占职工人数比例是：\n\n205 ÷ 3069 ≈ 6.68%\n\n答案为6.68%。'}
# {'id': 1206, 'question': '浙江航民股份有限公司2019年研发人员占职工人数比例是多少?保留2位小数。', 'answer': '根据【背景知识】，浙江航民股份有限公司2019年的职工人数为9633人，研发人员为918人。要求求出浙江航民股份有限公司2019年研发人员占职工人数比例。\n\n【解答】\n\n1. 计算浙江航民股份有限公司2019年研发人员占职工人数比例：918 ÷ 9633 × 100% ≈ 9.51%\n\n2. 根据计算结果，浙江航民股份有限公司2019年研发人员占职工人数比例约为9.51%。'}
# {'id': 1218, 'question': '长虹华意压缩机股份有限公司2019年的研发人员占职工人数的比例是多少？请保留两位小数。', 'answer': '根据提供的背景知识，长虹华意压缩机股份有限公司2019年的研发人员为570，职工人数为7802。因此，该公司2019年的研发人员占职工人数的比例为：\n\n570 / 7802 ≈ 0.0747\n\n答案保留两位小数，即74.7%。'}
# {'id': 1237, 'question': '裕兴股份在2019年的研发人员占职工人数比例是多少？请保留两位小数。', 'answer': '根据给出的背景知识，裕兴股份在2019年的研发人员为53人，职工人数为321人。所以，裕兴股份在2019年的研发人员占职工人数比例为：\n\n(53 / 321) * 100% ≈ 16.73%\n\n所以，裕兴股份在2019年的研发人员占职工人数比例约为16.73%。'}
# {'id': 1391, 'question': '浙江仙通2019年的研发人员占职工人数的比例是多少？请保留两位小数。', 'answer': '根据浙江仙通2019年报，研发人员比率为14.26。要求求出浙江仙通2019年的研发人员占职工人数的比例。\n\n【解答】\n1. 根据浙江仙通2019年报，研发人员比率为14.26。\n2. 要求求出浙江仙通2019年的研发人员占职工人数的比例，即研发人员数除以职工人数。\n3. 计算研发人员数：200人。\n4. 计算职工人数：1746人。\n5. 将研发人员数200除以职工人数1746，得到的结果为0.1177857。\n6. 将结果保留两位小数，得到答案为0.12。\n\n【答案】浙江仙通2019年的研发人员占职工人数的比例为0.12，保留两位小数。'}
# {'id': 3481, 'question': '在2019年，北京万集科技股份有限公司的研发人员占职工总人数的比例是多少？结果请保留两位小数。', 'answer': '根据给出的背景知识，2019年北京万集科技股份有限公司的研发人员为272人，职工总人数为1113人。因此，北京万集科技股份有限公司的研发人员占职工总人数的比例为：\n\n272 ÷ 1113 ≈ 0.2538 ≈ 25.4%\n\n答案：25.4%（保留两位小数）'}
# {'id': 3503, 'question': '沈阳化工股份有限公司2019年研发人员占职工人数比例是多少?保留2位小数。', 'answer': '根据沈阳化工股份有限公司2019年报,该公司研发人员为280人,职工人数为2868人。因此,沈阳化工股份有限公司2019年研发人员占职工人数比例为:\n\n280 / 2868 ≈ 0.9765\n\n答案保留2位小数,为0.97。'}
# {'id': 3683, 'question': '2019年安泰科技股份有限公司研发人员占职工人数比例为多少?保留2位小数。', 'answer': '根据【背景知识】，安泰科技2019年的职工人数为5565人，研发人员为851人，因此研发人员占职工人数比例为：\n\n851 ÷ 5565 ≈ 0.1509\n\n答案为0.15，保留2位小数。'}
# {'id': 3825, 'question': '陕西宝光真空电器股份有限公司在2019年的研发人员占职工人数比例是多少？请保留两位小数。', 'answer': '根据给出的背景知识，陕西宝光真空电器股份有限公司在2019年的职工人数为1322人，其中研发人员为163人。因此，陕西宝光真空电器股份有限公司在2019年的研发人员占职工人数比例为：\n\n163 / 1322 ≈ 0.1276\n\n答案为0.1276，保留两位小数。'}
# {'id': 4442, 'question': '新疆熙菱信息技术股份有限公司2019年研发人员占职工人数比例是多少?保留2位小数。', 'answer': '根据【背景知识】，新疆熙菱信息技术股份有限公司2019年的职工人数为386人，研发人员为288人。因此，该公司2019年研发人员占职工人数比例为：\n\n288 ÷ 386 × 100% ≈ 78.9%\n\n答案为78.9%（保留2位小数）。'}
# {'id': 4575, 'question': '2019年金牌厨柜家居科技股份有限公司研发人员占职工人数比例为多少?保留2位小数。', 'answer': '根据提供的背景知识，我们无法找到关于2019年金牌厨柜家居科技股份有限公司研发人员占职工人数比例的具体数据。请提供足够的相关信息，以便我们能够回答您的问题。'}
# {'id': 4602, 'question': '上海环境在2019年的研发人员占职工人数的比例是多少？请保留两位小数。', 'answer': '根据给出的背景知识，上海环境集团股份有限公司在2019年的研发人员为416人，职工人数为2535人。因此，上海环境在2019年的研发人员占职工人数的比例为：\n\n416 ÷ 2535 ≈ 16.0%\n\n答案保留两位小数，因此，上海环境在2019年的研发人员占职工人数的比例约为16.0%。'}
# {'id': 4975, 'question': '2019年赛伍技术研发人员占职工人数比例是多少?保留2位小数。', 'answer': '根据提供的【背景知识】，我们无法找到2019年赛伍技术研发人员占职工人数比例的数据。因此，我们无法回答该问题。答案为“根据已知信息无法回答该问题”。'}

# %% [raw]
# 正确0.1

# %%
s2 = []
for line in o:
    if '硕士及以上人员占' in line['question']:
        s2.append(line)

# %%
len(s2)
# Out:
# 45

# %%
s2[0]
# Out:
# {'id': 47,
#  'question': '华信新材在2019年的研发人员占职工人数比例是多少?请保留2位小数。',
#  'answer': '根据【背景知识】，华信新材在2019年的职工人数为400人，而研发人员为55人。因此，华信新材在2019年的研发人员占职工人数比例为：\n\n研发人员 ÷ 职工人数 = 55 ÷ 400 = 0.1375\n\n答案为0.1375，保留2位小数。'}

# %%
s2[1]
# Out:
# {'id': 145,
#  'question': '三棵树在2019年的研发人员占职工人数的比例是多少？请保留两位小数。',
#  'answer': '根据【背景知识】，我们得知三棵树在2019年的职工人数为5163人，研发人员为583人，且研发人员比率为11.29。\n\n要求计算三棵树在2019年的研发人员占职工人数的比例。\n\n【解答】\n\n根据公式，研发人员占职工人数的比例 = 研发人员 / 职工人数 × 100%。\n\n将数据代入公式，得到：11.29 / 5163 × 100% ≈ 2.15%。\n\n所以，三棵树在2019年的研发人员占职工人数的比例约为2.15%。'}

# %%
t="""企业研发经费与利润比值=研发费用/净利润
企业研发经费与营业收入比值=研发费用/营业收入
研发人员占职工人数比例=研发人员数/职工总数
流动比率=流动资产/流动负债
速动比率=(流动资产-存货)/流动负债
企业硕士及以上人员占职工人数比例=(硕士人数 + 博士及以上人数)/职工总数
企业研发经费占费用比例=研发费用/(销售费用+财务费用+管理费用+研发费用
营业利润率=营业利润/营业收入
资产负债比率=总负债/资产总额
现金比率=货币资金/流动负债
非流动负债比率=非流动负债/总负债
流动负债比率=流动负债/总负债
净资产收益率=净利润/净资产
净利润率=净利润/营业收入
营业成本率=营业成本/营业收入
管理费用率=管理费用/营业收入
财务费用率=财务费用/营业收入
毛利率=(营业收入-营业成本)/营业收入
净资产增长率=(净资产-上年净资产)/上年净资产
三费比重=(销售费用+管理费用+财务费用)/营业收入
投资收益占营业收入比率=投资收益/营业收入
销售费用增长率=(销售费用-上年销售费用)/上年销售费用
财务费用增长率=(财务费用-上年财务费用)/上年财务费用
管理费用增长率=(管理费用-上年管理费用)/上年管理费用
研发费用增长率=(研发费用-上年研发费用)/上年研发费用
总负债增长率=(总负债-上年总负债)/上年总负债
流动负债增长率=(流动负债-上年流动负债)/上年流动负债
货币资金增长率=(货币资金-上年货币资金)/上年货币资金
固定资产增长率=(固定资产-上年固定资产)/上年固定资产
无形资产增长率=(无形资产-上年无形资产)/上年无形资产
总资产增长率=(资产总额-上年资产总额)/上年资产总额
营业收入增长率=(营业收入-上年营业收入)/上年营业收入
营业利润增长率=(营业利润-上年营业利润)/上年营业利润
净利润增长率=(净利润-上年净利润)/上年净利润
现金及现金等价物增长率=(现金及现金等价物-上年现金及现金等价物)/上年现金及现金等价物"""

# %%
formulas = t.split('\n')

# %%
from collections import defaultdict

# %%
formula_dict = defaultdict()

# %%
for f in formulas:
    formula_dict[f.split('=')[0]]=f

# %%
formula_dict
# Out:
# defaultdict(None,
#             {'企业研发经费与利润比值': '企业研发经费与利润比值=研发费用/净利润',
#              '企业研发经费与营业收入比值': '企业研发经费与营业收入比值=研发费用/营业收入',
#              '研发人员占职工人数比例': '研发人员占职工人数比例=研发人员数/职工总数',
#              '流动比率': '流动比率=流动资产/流动负债',
#              '速动比率': '速动比率=(流动资产-存货)/流动负债',
#              '企业硕士及以上人员占职工人数比例': '企业硕士及以上人员占职工人数比例=(硕士人数 + 博士及以上人数)/职工总数',
#              '企业研发经费占费用比例': '企业研发经费占费用比例=研发费用/(销售费用+财务费用+管理费用+研发费用',
#              '营业利润率': '营业利润率=营业利润/营业收入',
#              '资产负债比率': '资产负债比率=总负债/资产总额',
#              '现金比率': '现金比率=货币资金/流动负债',
#              '非流动负债比率': '非流动负债比率=非流动负债/总负债',
#              '流动负债比率': '流动负债比率=流动负债/总负债',
#              '净资产收益率': '净资产收益率=净利润/净资产',
#              '净利润率': '净利润率=净利润/营业收入',
#              '营业成本率': '营业成本率=营业成本/营业收入',
#              '管理费用率': '管理费用率=管理费用/营业收入',
#              '财务费用率': '财务费用率=财务费用/营业收入',
#              '毛利率': '毛利率=(营业收入-营业成本)/营业收入',
#              '净资产增长率': '净资产增长率=(净资产-上年净资产)/上年净资产',
#              '三费比重': '三费比重=(销售费用+管理费用+财务费用)/营业收入',
#              '投资收益占营业收入比率': '投资收益占营业收入比率=投资收益/营业收入',
#              '销售费用增长率': '销售费用增长率=(销售费用-上年销售费用)/上年销售费用',
#              '财务费用增长率': '财务费用增长率=(财务费用-上年财务费用)/上年财务费用',
#              '管理费用增长率': '管理费用增长率=(管理费用-上年管理费用)/上年管理费用',
#              '研发费用增长率': '研发费用增长率=(研发费用-上年研发费用)/上年研发费用',
#              '总负债增长率': '总负债增长率=(总负债-上年总负债)/上年总负债',
#              '流动负债增长率': '流动负债增长率=(流动负债-上年流动负债)/上年流动负债',
#              '货币资金增长率': '货币资金增长率=(货币资金-上年货币资金)/上年货币资金',
#              '固定资产增长率': '固定资产增长率=(固定资产-上年固定资产)/上年固定资产',
#              '无形资产增长率': '无形资产增长率=(无形资产-上年无形资产)/上年无形资产',
#              '总资产增长率': '总资产增长率=(资产总额-上年资产总额)/上年资产总额',
#              '营业收入增长率': '营业收入增长率=(营业收入-上年营业收入)/上年营业收入',
#              '营业利润增长率': '营业利润增长率=(营业利润-上年营业利润)/上年营业利润',
#              '净利润增长率': '净利润增长率=(净利润-上年净利润)/上年净利润',
#              '现金及现金等价物增长率': '现金及现金等价物增长率=(现金及现金等价物-上年现金及现金等价物)/上年现金及现金等价物'})

# %%
len(formula_dict)
# Out:
# 35

# %%
financial_formulas = {
    "资产负债比率": (["总负债", "总资产"], "总负债 / 总资产 × 100"),
    "营业利润率": (["营业利润", "营业收入"], "营业利润 / 营业收入 × 100"),
    "速动比率": (["流动资产合计", "存货", "流动负债合计"], "(流动资产合计 - 存货) / 流动负债合计"),
    "流动比率": (["流动资产合计", "流动负债合计"], "流动资产合计 / 流动负债合计"),
    "现金比率": (["货币资金", "流动负债合计"], "货币资金 / 流动负债合计"),
    "净利润率": (["净利润", "营业收入"], "净利润 / 营业收入 × 100"),
    "毛利率": (["营业收入", "营业成本"], "(营业收入-营业成本) / 营业收入 × 100"),
    "财务费用率": (["财务费用", "营业收入"], "财务费用 / 营业收入 × 100"),
    "营业成本率": (["营业成本", "营业收入"], "营业成本 / 营业收入 × 100"),
    "管理费用率": (["管理费用", "营业收入"], "管理费用 / 营业收入 × 100"),
    "流动负债比率": (["流动负债合计", "总负债"], "流动负债合计 / 总负债 × 100"),
    "非流动负债比率": (["非流动负债合计", "总负债"], "非流动负债合计 / 总负债× 100"),
    "投资收益占营业收入比率": (["投资收益", "营业收入"], "投资收益 / 营业收入× 100"),
    "研发经费与利润比值": (["研发费用", "净利润"], "研发费用 / 净利润"),
    "三费比重": (["管理费用", "财务费用","销售费用","营业收入"],"(管理费用+财务费用+销售费用) / 营业收入"),
    "研发经费与营业收入比值": (["研发费用", "营业收入"], "研发费用 / 营业收入"),
    "企业研发经费占费用": (["销售费用","财务费用","管理费用","研发费用"], "研发费用 / (研发费用+管理费用+财务费用+销售费用)"),
    }

# %%
len(financial_formulas)
# Out:
# 17

# %%
[x for x in formula_dict.keys()-financial_formulas.keys() if '增长率' not in x]
# Out:
# ['企业研发经费与利润比值',
#  '企业研发经费与营业收入比值',
#  '研发人员占职工人数比例',
#  '企业研发经费占费用比例',
#  '净资产收益率',
#  '企业硕士及以上人员占职工人数比例']
